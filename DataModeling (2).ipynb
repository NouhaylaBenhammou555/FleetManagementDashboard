# %%
import plotly.express as px 
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
import dateutil
import datetime
import chart_studio.plotly as py
 
import seaborn as sns 
import folium
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import altair as alt

import json


# %matplotlib inline
import cufflinks as cf
import math
import random 
from datetime import timedelta
import plotly
import plotly.offline as pyo
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
pyo.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("MyDataset.csv")
df_1=pd.DataFrame(df,columns=['Type Camion','vehicle_no','Numéro Garage','km_driven','fuel type','transmission' ])
df_1.style.background_gradient(cmap='Reds')
df_1
# Out:
#              Type Camion  vehicle_no  Numéro Garage  km_driven fuel type  \
# 0    Camion frigorifique    KA590408              1     145500    Diesel
# 1    Camion frigorifique  TN30BC5917              2     120000    Diesel
# 2    Camion frigorifique  TN22AR2748              3     140000    Petrol
# 3    Camion frigorifique  TN28AQ0781              4     127000    Diesel
# 4    Camion frigorifique   TN68F1722              2     120000    Petrol
# ..                   ...         ...            ...        ...       ...
# 494  Camion frigorifique   TN88D4134              3      70000    Diesel
# 495  Camion frigorifique  TN30BC5982              4      70000    Petrol
# 496  Camion frigorifique  TN18AB5514              4      45000    Diesel
# 497  Camion frigorifique   TN88D3900              4      40000    Petrol
# 498  Camion frigorifique   TN83Q3845              4      30000    Diesel
#
#     transmission
# 0         Manual
# 1         Manual
# 2         Manual
# 3         Manual
# 4         Manual
# ..           ...
# 494       Manual
# 495       Manual
# 496       Manual
# 497    Automatic
# 498       Manual
#
# [499 rows x 6 columns]

# %%
  
df_fuel=pd.read_csv("MyDataset.csv")
dff=df[['Type Camion','transmission']]
dff=dff.groupby(dff.columns.tolist()).size().reset_index().\
    rename(columns={0:'nombre'})
dff
#fig=fig=px.bar(dff,x='Type Camion',y='transmission',text='transmission',color='transmission',barmode='group')
 
#fig
# Out:
#            Type Camion transmission  nombre
# 0  Camion frigorifique    Automatic       8
# 1  Camion frigorifique       Manual     113
# 2         Cargo Camion    Automatic      43
# 3         Cargo Camion       Manual     108
# 4         Grand Camion    Automatic      45
# 5         Grand Camion       Manual     182

# %%
df_fuel=pd.read_csv("MyDataset.csv")
dff=df[['Type Camion','transmission']]
dff=dff.groupby(dff.columns.tolist()).size().reset_index().\
    rename(columns={0:'nombre'})
 
fig=fig=px.bar(dff,x='Type Camion',y='nombre',text='transmission',color='transmission',barmode='group')
 
fig.show()
fig.write_html("transmission.html")
# Out:
# <div>                            <div id="0b6fc1e5-188c-4c1f-b7cd-e9abc3ff8617" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b6fc1e5-188c-4c1f-b7cd-e9abc3ff8617")) {                    Plotly.newPlot(                        "0b6fc1e5-188c-4c1f-b7cd-e9abc3ff8617",                        [{"alignmentgroup": "True", "hovertemplate": "transmission=%{text}<br>Type Camion=%{x}<br>nombre=%{y}<extra></extra>", "legendgroup": "Automatic", "marker": {"color": "#636efa"}, "name": "Automatic", "offsetgroup": "Automatic", "orientation": "v", "showlegend": true, "text": ["Automatic", "Automatic", "Automatic"], "textposition": "auto", "type": "bar", "x": ["Camion frigorifique", "Cargo Camion", "Grand Camion"], "xaxis": "x", "y": [8, 43, 45], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "transmission=%{text}<br>Type Camion=%{x}<br>nombre=%{y}<extra></extra>", "legendgroup": "Manual", "marker": {"color": "#EF553B"}, "name": "Manual", "offsetgroup": "Manual", "orientation": "v", "showlegend": true, "text": ["Manual", "Manual", "Manual"], "textposition": "auto", "type": "bar", "x": ["Camion frigorifique", "Cargo Camion", "Grand Camion"], "xaxis": "x", "y": [113, 108, 182], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "transmission"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": ...

# %%
 df_us=pd.read_csv("MyDataset.csv")
fig=px.bar(df_us,x='state_name',y='city',text='state_name',color='state_name')

fig
# Out:
# <div>                            <div id="3cc8fe0c-c415-47d9-aa46-ec3bf046c70c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cc8fe0c-c415-47d9-aa46-ec3bf046c70c")) {                    Plotly.newPlot(                        "3cc8fe0c-c415-47d9-aa46-ec3bf046c70c",                        [{"alignmentgroup": "True", "hovertemplate": "state_name=%{text}<br>city=%{y}<extra></extra>", "legendgroup": "New York", "marker": {"color": "#636efa"}, "name": "New York", "offsetgroup": "New York", "orientation": "v", "showlegend": true, "text": ["New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York"], "textposition": "auto", "type": "bar", "x": ["New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York", "New York"], "xaxis": "x", "y": ["New York", "Brooklyn", "Queens", "Manhattan", "Bronx", "Buffalo", "Rochester", "Albany", "Staten Island", "Syracuse", "Poughkeepsie", "Yonkers", "Binghamton", "Utica"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "state_name=%{text}<br>city=%{y}<extra></extra>", "legendgroup": "California", "marker": {"color": "#EF553B"}, "name": "California", "offsetgroup": "California", "orientation": "v", "showlegend": true, "text": ["California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California"], "textposition": "auto", "type": "bar", "x": ["California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "California", "Califo ...

# %%
 
df=pd.read_csv("MyDataset.csv")
df_1=pd.DataFrame(df,columns=[ 'vehicle_no','Driver_id', 'Driver name','Availability' ])
 
df
# Out:
#              Type Camion Type de marchandise Temperature minimale  \
# 0    Camion frigorifique    Produit laitiers                   2℃
# 1    Camion frigorifique    Produit laitiers                   2℃
# 2    Camion frigorifique    Produit laitiers                   2℃
# 3    Camion frigorifique    Produit laitiers                   2℃
# 4    Camion frigorifique    Produit laitiers                   2℃
# ..                   ...                 ...                  ...
# 494  Camion frigorifique            volaille                   7℃
# 495  Camion frigorifique            volaille                   7℃
# 496  Camion frigorifique            volaille                   7℃
# 497  Camion frigorifique            volaille                   7℃
# 498  Camion frigorifique            volaille                   7℃
#
#     Température maximale transmission  km_driven fuel type  \
# 0                    22℃       Manual     145500    Diesel
# 1                    22℃       Manual     120000    Diesel
# 2                    22℃       Manual     140000    Petrol
# 3                    22℃       Manual     127000    Diesel
# 4                    22℃       Manual     120000    Petrol
# ..                   ...          ...        ...       ...
# 494                  15℃       Manual      70000    Diesel
# 495                  15℃       Manual      70000    Petrol
# 496                  15℃       Manual      45000    Diesel
# 497                  15℃    Automatic      40000    Petrol
# 498                  15℃       Manual      30000    Diesel
#
#     Average mileage per week  speed    Availability  Numéro Garage  \
# 0                  23.4 kmpl     26       Available              1
# 1                 21.14 kmpl     30  Not Availabale              2
# 2                  17.7 kmpl     38       Available              3
# 3                  23.0 kmpl     36  Not Availabale              4
# 4                  16.1 kmpl     46  Not Availabale              2
# ..                       ...    ...             ...            ...
# 494               20.54 kmpl     39  Not Availabale              3
# 495                18.6 kmpl     35  Not Availabale              4
# 496               23.59 kmpl     52  Not Availabale              4
# 497                18.9 kmpl     48  Not Availabale              4
# 498                28.4 kmpl     48  Not Availabale              4
#
#      vehicle_no  Average Distance driven per week    Driver name  Driver_id   \
# 0      KA590408                             320.0            NaN         584
# 1    TN30BC5917                             103.0         RAMESH         586
# 2    TN22AR2748                             300.0           GIRI         742
# 3    TN28AQ0781                              61.0           RAVI          10
# 4     TN68F1722                             240.0          TAMIL          83
# ..          ...                               ...            ...         ...
# 494   TN88D4134                              20.0       SUDHAKAR         578
# 495  TN30BC5982                             103.0  SENTHIL KUMAR         758
# 496  TN18AB5514                             170.0        KESAVEN         244
# 497   TN88D3900                               3.0        KUMARAN         569
# 498   TN83Q3845                             400.0    MUTHUVELU S         880
#
#             city  state_name  latitude  longitude   Time
# 0       New York    New York   40.6943   -73.9249  11:11
# 1    Los Angeles  California   34.1139  -118.4068  11:23
# 2        Chicago    Illinois   41.8373   -87.6862  11:34
# 3          Miami     Florida   25.7839   -80.2102  11:45
# 4         Dallas       Texas   32.7936   -96.7662  12:00
# ..           ...         ...       ...        ...    ...
# 494       Edmond    Oklahoma   35.6689   -97.4159  04:05
# 495      Hanford  California   36.3274  -119.6549  04:16
# 496     Dearborn    Michigan   42.3127   -83.2129  04:29
# 497      Livonia    Michigan   42.3972   -83.3733  04:46
# 498   South Gate  California   33.9448  -118.1926  05:10
#
# [499 rows x 20 columns]

# %%
 df=pd.read_csv("MyDataset.csv")
df_1=df[[ 'vehicle_no', 'Driver name','Availability' ]]
 df_1
# Out:
#      vehicle_no    Driver name    Availability
# 0      KA590408            NaN       Available
# 1    TN30BC5917         RAMESH  Not Availabale
# 2    TN22AR2748           GIRI       Available
# 3    TN28AQ0781           RAVI  Not Availabale
# 4     TN68F1722          TAMIL  Not Availabale
# ..          ...            ...             ...
# 494   TN88D4134       SUDHAKAR  Not Availabale
# 495  TN30BC5982  SENTHIL KUMAR  Not Availabale
# 496  TN18AB5514        KESAVEN  Not Availabale
# 497   TN88D3900        KUMARAN  Not Availabale
# 498   TN83Q3845    MUTHUVELU S  Not Availabale
#
# [499 rows x 3 columns]

# %%
 
df_fuel=pd.read_csv("MyDataset.csv")
dff=df[['Type Camion','fuel type']]
dff=dff.groupby(dff.columns.tolist()).size().reset_index().\
    rename(columns={0:'nombre'})
 
fig=fig=px.bar(dff,x='Type Camion',y='nombre',text='fuel type',color='fuel type',barmode='group')
 
fig.iplot()
# Out:
# <div>                            <div id="9861edeb-62ca-4c79-810b-4285db7426e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("9861edeb-62ca-4c79-810b-4285db7426e7")) {                    Plotly.newPlot(                        "9861edeb-62ca-4c79-810b-4285db7426e7",                        [{"alignmentgroup": "True", "hovertemplate": "fuel type=%{text}<br>Type Camion=%{x}<br>nombre=%{y}<extra></extra>", "legendgroup": "Diesel", "marker": {"color": "#636efa"}, "name": "Diesel", "offsetgroup": "Diesel", "orientation": "v", "showlegend": true, "text": ["Diesel", "Diesel", "Diesel"], "textposition": "auto", "type": "bar", "x": ["Camion frigorifique", "Cargo Camion", "Grand Camion"], "xaxis": "x", "y": [64, 50, 118], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "fuel type=%{text}<br>Type Camion=%{x}<br>nombre=%{y}<extra></extra>", "legendgroup": "LPG", "marker": {"color": "#EF553B"}, "name": "LPG", "offsetgroup": "LPG", "orientation": "v", "showlegend": true, "text": ["LPG", "LPG"], "textposition": "auto", "type": "bar", "x": ["Camion frigorifique", "Cargo Camion"], "xaxis": "x", "y": [1, 1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "fuel type=%{text}<br>Type Camion=%{x}<br>nombre=%{y}<extra></extra>", "legendgroup": "Petrol", "marker": {"color": "#00cc96"}, "name": "Petrol", "offsetgroup": "Petrol", "orientation": "v", "showlegend": true, "text": ["Petrol", "Petrol", "Petrol"], "textposition": "auto", "type": "bar", "x": ["Camion frigorifique", "Cargo Camion", "Grand Camion"], "xaxis": "x", "y": [56, 98, 108], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "fuel type=%{text}<br>Type Camion=%{x}<br>nombre=%{y}<extra></extra>", "legendgroup": "CNG", "marker": {"color": "#ab63fa"}, "name": "CNG", "offsetgroup": "CNG", "orientation": "v", "showlegend": true, "text": ["CNG", "CNG"], "textposition": "auto", "type": "bar", "x": ["Cargo Camion", "Grand Camion"], "xaxis": "x", "y": [2, 1], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "fuel type"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1 ...

# %%
#plt.rcParams['figure.figsize']=15,10
df.plot(kind='bar',x='fuel type',y='speed')
df.plot(kind='bar',x='fuel type',y='speed')
# Out:
# <AxesSubplot:xlabel='fuel type'>

# %%
df=pd.read_csv("MyDataset.csv") 
fig_pie = px.pie(data_frame=df,names='Type de marchandise',template="gridon")
fig_pie.iplot()
# Out:
# <div>                            <div id="16004588-d534-4399-80e0-e9da6b3373b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("16004588-d534-4399-80e0-e9da6b3373b9")) {                    Plotly.newPlot(                        "16004588-d534-4399-80e0-e9da6b3373b9",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Type de marchandise=%{label}<extra></extra>", "labels": ["Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produit laitiers", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Produits d'hygi\u00e8ne", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Surgel\u00e9s", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "Autres Aliments", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "L\u00e9gumes", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Conserves", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "Farine", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en grains", "C\u00e9r\u00e9ales en g ...

# %%
import folium
import pandas as pd
from folium import FeatureGroup
from folium.plugins import MarkerCluster

#Create the base Map
m = folium.Map(location=[37.090240,-95.712891], tiles='OpenStreetMap', zoom_start=5)

#Read the data
df = pd.read_csv("MyDataset.csv")

#Create the markers
markerCluster = MarkerCluster().add_to(m)
for i, row in df.iterrows():
    lat  = df.at[i,'latitude']
    lng = df.at[i,'longitude']
    camion = df.at[i,'Type Camion']
    popup = df.at[i,'Type Camion'] 

    if camion == 'Camion frigorifique':
        color = 'blue'
    elif camion == 'Grand Camion':
        color = 'red'
    else:
        color = 'purple'

    folium.Marker(location=[lat, lng],popup=camion, icon=folium.Icon(color=color)).add_to(markerCluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_41e69bfe99914c76927bd3b45717063a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_41e69bfe99914c76927bd3b45717063a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %%
 
df=pd.read_csv("MyDataset.csv") 
fig_pie = px.pie(data_frame=df,names='Availability',template="gridon")
fig_pie
# Out:
# <div>                            <div id="6ad2fd1f-1d7b-43de-a564-2197983516da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ad2fd1f-1d7b-43de-a564-2197983516da")) {                    Plotly.newPlot(                        "6ad2fd1f-1d7b-43de-a564-2197983516da",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Availability=%{label}<extra></extra>", "labels": ["Available", "Not Availabale", "Available", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Available", "Available", "Available", "Available", "Available", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Available", "Available", "Available", "Available", "Available", "Not Availabale", "Not Availabale", "Available", "Available", "Available", "Available", "Available", "Not Availabale", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Available", "Not Availabale", "Available", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Available", "Available", "Available", "Available", "Available", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Not Availabale", "Available", "Available", "Available", "Available", "Available", "Not Availabale", "Not Availabale", "Available", "Available", "Available", "Available", "Available", "Not Availabale", "Availabl ...
